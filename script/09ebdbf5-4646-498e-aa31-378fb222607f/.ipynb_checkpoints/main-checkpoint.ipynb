# %%
import pandas as pd
import json
from  functools import reduce
import os
import sys

# %%
params = "/ssd1/wy/workspace2/nextflow_workspace/1c48821a-f430-45af-a479-dc400476147e/09ebdbf5-4646-498e-aa31-378fb222607f/c9358bbc-acc7-4405-9aea-a006d06d5e61/params.json"
output="/ssd1/wy/workspace2/nextflow_workspace/1c48821a-f430-45af-a479-dc400476147e/09ebdbf5-4646-498e-aa31-378fb222607f/c9358bbc-acc7-4405-9aea-a006d06d5e61/output"

# %%
params
# Out:
# '/ssd1/wy/workspace2/nextflow_workspace/1c48821a-f430-45af-a479-dc400476147e/09ebdbf5-4646-498e-aa31-378fb222607f/c9358bbc-acc7-4405-9aea-a006d06d5e61/params.json'

# %%
term
# Out:
# 'pathabundance_rpkm'

# %%
with open(params,"r") as f:
    params_json = json.load(f)
humann_profile = params_json['humann_profile']
term = params_json['term']

# %%
humann_profile_path = [item[term] for item in humann_profile]

# %%
def get_df(item,term):
    file_name = os.path.basename(item)
    term = term.replace("_",".")
    file_name = file_name.replace(f"_{term}.tsv","")
    file_name = file_name.replace(f".{term}.txt","")
    df = pd.read_csv(item,sep="\t")
    df.columns = ["term",file_name]
    df = df.query("not term.str.contains('\\|')")
    return df

# %%
# get_df(humann_profile_path[0],term)

# %%
humann_profile_df = [get_df(item,term) for item in humann_profile_path]

# %%
# humann_profile_df[0]

# %%
humann_profile_df[0]
# Out:
#                                                    term  S-30-D-021
# 0     PWY0-1586: peptidoglycan maturation (meso-diam...    0.010700
# 45         PWY-6700: queuosine biosynthesis I (de novo)    0.010539
# 112   PWY-6147: 6-hydroxymethyl-dihydropterin diphos...    0.010203
# 148   PWY-7229: superpathway of adenosine nucleotide...    0.009823
# 181   PEPTIDOGLYCANSYN-PWY: peptidoglycan biosynthes...    0.009743
# ...                                                 ...         ...
# 5144        KETOGLUCONMET-PWY: ketogluconate metabolism    0.000008
# 5145    PWY-7391: isoprene biosynthesis II (engineered)    0.000006
# 5147  PWY-6435: 4-hydroxybenzoate biosynthesis III (...    0.000004
# 5148      PWY490-3: nitrate reduction VI (assimilatory)    0.000004
# 5150             PWY-6215: 4-chlorobenzoate degradation    0.000003
#
# [336 rows x 2 columns]

# %%
humann_profile_merge_df = reduce(lambda x,y: pd.merge(x,y,on="term",how="outer"),humann_profile_df ).fillna(0)

# %%
humann_profile_merge_df.memory_usage(deep=True).sum()
# Out:
# 1406445

# %%
285313423/1024/1024
# Out:
# 272.09608364105225

# %%
humann_profile_merge_df.to_csv(f"{output}/{term}.tsv", index=False,sep="\t")

# %%
# humann_profile_merge_df.to_excel(f"{output}/{term}.xlsx", index=False)

# %%
humann_profile_merge_df
# Out:
#                                                   term  S-30-D-021  S-30-115  \
# 0    PWY0-1586: peptidoglycan maturation (meso-diam...    0.010700  0.010705
# 1         PWY-6700: queuosine biosynthesis I (de novo)    0.010539  0.009160
# 2    PWY-6147: 6-hydroxymethyl-dihydropterin diphos...    0.010203  0.007129
# 3    PWY-7229: superpathway of adenosine nucleotide...    0.009823  0.009549
# 4    PEPTIDOGLYCANSYN-PWY: peptidoglycan biosynthes...    0.009743  0.008336
# ..                                                 ...         ...       ...
# 606                 PWY-7347: sucrose biosynthesis III    0.000000  0.000000
# 607                  PWY-6763: salicortin biosynthesis    0.000000  0.000000
# 608                 PWY66-201: nicotine degradation IV    0.000000  0.000000
# 609  4-HYDROXYMANDELATE-DEGRADATION-PWY: 4-hydroxym...    0.000000  0.000000
# 610                    PWY-7800: Ac/N-end rule pathway    0.000000  0.000000
#
#      S-30-100  S-30-106  F-30-095  S-30-085  S-30-136  F-30-140  F-30-D-030  \
# 0    0.015029  0.013768  0.005382  0.012155  0.015697  0.008570    0.010015
# 1    0.008037  0.009779  0.008412  0.010114  0.009105  0.007054    0.005236
# 2    0.006323  0.008243  0.002063  0.008910  0.007749  0.003168    0.003633
# 3    0.008068  0.008337  0.004508  0.011312  0.009141  0.005292    0.006716
# 4    0.007160  0.007861  0.009694  0.008738  0.008398  0.007764    0.007221
# ..        ...       ...       ...       ...       ...       ...         ...
# 606  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 607  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 608  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 609  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 610  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
#
#      ...  S-30-D-049  F-30-D-046  F-30-D-069  F-30-D-071  S-30-096  F-30-175  \
# 0    ...    0.012350    0.007846    0.006360    0.012767  0.010686  0.009616
# 1    ...    0.008789    0.012181    0.010497    0.010267  0.010214  0.006644
# 2    ...    0.007739    0.005000    0.001285    0.000583  0.007848  0.001363
# 3    ...    0.009397    0.006287    0.003875    0.006282  0.009930  0.007055
# 4    ...    0.008427    0.011607    0.010918    0.009771  0.009750  0.009774
# ..   ...         ...         ...         ...         ...       ...       ...
# 606  ...    0.000000    0.000000    0.000000    0.000000  0.000000  0.000000
# 607  ...    0.000000    0.000000    0.000000    0.000000  0.000000  0.000000
# 608  ...    0.000000    0.000000    0.000000    0.000000  0.000000  0.000000
# 609  ...    0.000000    0.000000    0.000000    0.000000  0.000000  0.000000
# 610  ...    0.000000    0.000000    0.000000    0.000000  0.000000  0.000000
#
#      F-30-160  S-30-D-034  F-30-D-065  F-30-102
# 0    0.010232    0.014208    0.017968  0.010016
# 1    0.007050    0.009398    0.014068  0.007718
# 2    0.004094    0.008430    0.014677  0.003661
# 3    0.005566    0.009617    0.002736  0.007187
# 4    0.008189    0.008570    0.017372  0.008990
# ..        ...         ...         ...       ...
# 606  0.000000    0.000000    0.000000  0.000000
# 607  0.000000    0.000000    0.000000  0.000000
# 608  0.000000    0.000000    0.000000  0.000000
# 609  0.000000    0.000000    0.000000  0.000000
# 610  0.000000    0.000000    0.000000  0.000000
#
# [611 rows x 275 columns]

# %%
[(item['sample_name'] ,item['sample_name'] )for item in  humann_profile]
# Out:
# ['S-30-D-021',
#  'S-30-115',
#  'S-30-100',
#  'S-30-106',
#  'F-30-095',
#  'S-30-085',
#  'S-30-136',
#  'F-30-140',
#  'F-30-D-030',
#  'S-30-154',
#  'S-30-099',
#  'F-30-D-028',
#  'S-30-D-053',
#  'F-30-153',
#  'F-30-131',
#  'F-30-091',
#  'S-30-126',
#  'F-30-109',
#  'S-30-D-001',
#  'S-30-143',
#  'S-30-D-063',
#  'F-30-122',
#  'F-30-D-006',
#  'S-30-133',
#  'F-30-D-050',
#  'S-30-114',
#  'S-30-121',
#  'F-30-129',
#  'S-30-146',
#  'F-30-093',
#  'S-30-086',
#  'F-30-142',
#  'S-30-174',
#  'F-30-072',
#  'F-30-D-064',
#  'S-30-177',
#  'S-30-D-033',
#  'F-30-D-018',
#  'S-30-151',
#  'F-30-162',
#  'F-30-D-013',
#  'F-30-132',
#  'S-30-D-045',
#  'S-30-069',
#  'F-30-069',
#  'F-30-080',
#  'F-30-114',
#  'F-30-D-067',
#  'S-30-081',
#  'S-30-158',
#  'S-30-172',
#  'S-30-D-042',
#  'S-30-D-051',
#  'S-30-D-026',
#  'S-30-D-015',
#  'S-30-110',
#  'S-30-137',
#  'F-30-116',
#  'F-30-123',
#  'S-30-D-038',
#  'S-30-D-058',
#  'S-30-095',
#  'S-30-D-046',
#  'S-30-084',
#  'F-30-130',
#  'S-30-D-039',
#  'F-30-148',
#  'S-30-D-064',
#  'F-30-D-053',
#  'S-30-D-052',
#  'S-30-173',
#  'F-30-D-073',
#  'F-30-D-027',
#  'F-30-159',
#  'S-30-078',
#  'F-30-124',
#  'S-30-D-032',
#  'S-30-D-041',
#  'F-30-111',
#  'F-30-121',
#  'S-30-D-012',
#  'F-30-D-035',
#  'F-30-D-014',
#  'F-30-D-049',
#  'S-30-D-065',
#  'S-30-D-030',
#  'F-30-D-001',
#  'F-30-D-033',
#  'S-30-129',
#  'F-30-110',
#  'F-30-172',
#  'F-30-106',
#  'S-30-D-062',
#  'S-30-183',
#  'S-30-140',
#  'S-30-125',
#  'F-30-D-017',
#  'F-30-D-048',
#  'S-30-112',
#  'F-30-D-042',
#  'S-30-117',
#  'F-30-D-045',
#  'F-30-090',
#  'S-30-D-035',
#  'F-30-068',
#  'F-30-D-019',
#  'S-30-D-017',
#  'F-30-143',
#  'S-30-D-005',
#  'S-30-D-006',
#  'S-30-164',
#  'F-30-100',
#  'S-30-132',
#  'F-30-173',
#  'S-30-077',
#  'F-30-088',
#  'F-30-D-008',
#  'F-30-115',
#  'S-30-103',
#  'S-30-D-040',
#  'S-30-D-044',
#  'F-30-147',
#  'S-30-072',
#  'S-30-156',
#  'F-30-133',
#  'F-30-135',
#  'F-30-146',
#  'S-30-D-020',
#  'S-30-D-004',
#  'F-30-156',
#  'S-30-D-071',
#  'S-30-D-043',
#  'F-30-D-034',
#  'F-30-D-058',
#  'F-30-112',
#  'S-30-179',
#  'S-30-124',
#  'S-30-D-061',
#  'F-30-D-047',
#  'S-30-135',
#  'S-30-119',
#  'S-30-142',
#  'F-30-D-016',
#  'S-30-D-073',
#  'S-30-D-069',
#  'S-30-D-031',
#  'S-30-D-016',
#  'S-30-D-028',
#  'F-30-085',
#  'F-30-D-077',
#  'F-30-D-011',
#  'S-30-D-047',
#  'F-30-D-029',
#  'F-30-D-026',
#  'S-30-101',
#  'F-30-D-052',
#  'F-30-D-038',
#  'S-30-D-008',
#  'F-30-D-044',
#  'S-30-098',
#  'S-30-071',
#  'F-30-D-072',
#  'S-30-131',
#  'F-30-071',
#  'S-30-116',
#  'S-30-D-067',
#  'S-30-088',
#  'S-30-102',
#  'S-30-D-027',
#  'F-30-099',
#  'S-30-D-036',
#  'S-30-D-048',
#  'S-30-D-010',
#  'F-30-120',
#  'S-30-145',
#  'S-30-120',
#  'F-30-D-007',
#  'S-30-186',
#  'F-30-078',
#  'F-30-145',
#  'S-30-D-011',
#  'F-30-D-015',
#  'F-30-098',
#  'F-30-144',
#  'F-30-D-010',
#  'F-30-179',
#  'F-30-D-043',
#  'F-30-D-051',
#  'F-30-083',
#  'F-30-164',
#  'S-30-D-013',
#  'F-30-D-037',
#  'F-30-094',
#  'S-30-068',
#  'F-30-D-066',
#  'F-30-D-005',
#  'S-30-180',
#  'F-30-174',
#  'S-30-094',
#  'F-30-177',
#  'S-30-D-066',
#  'F-30-125',
#  'S-30-D-029',
#  'F-30-D-063',
#  'F-30-081',
#  'F-30-070',
#  'F-30-D-004',
#  'F-30-D-032',
#  'S-30-163',
#  'F-30-077',
#  'F-30-D-012',
#  'S-30-D-068',
#  'S-30-D-072',
#  'S-30-091',
#  'F-30-103',
#  'S-30-122',
#  'F-30-D-039',
#  'F-30-D-020',
#  'S-30-162',
#  'S-30-111',
#  'S-30-D-050',
#  'F-30-D-062',
#  'F-30-180',
#  'F-30-D-009',
#  'S-30-157',
#  'F-30-119',
#  'F-30-096',
#  'S-30-123',
#  'S-30-093',
#  'F-30-D-036',
#  'S-30-153',
#  'S-30-D-009',
#  'S-30-D-018',
#  'S-30-147',
#  'S-30-D-019',
#  'S-30-D-025',
#  'S-30-D-007',
#  'F-30-163',
#  'F-30-D-040',
#  'S-30-160',
#  'S-30-175',
#  'S-30-144',
#  'F-30-D-031',
#  'S-30-070',
#  'F-30-D-025',
#  'S-30-D-037',
#  'S-30-082',
#  'F-30-D-021',
#  'S-30-159',
#  'F-30-D-041',
#  'F-30-D-061',
#  'S-30-D-014',
#  'F-30-086',
#  'S-30-080',
#  'F-30-D-068',
#  'S-30-090',
#  'S-30-109',
#  'F-30-126',
#  'S-30-148',
#  'S-30-130',
#  'F-30-186',
#  'F-30-183',
#  'S-30-083',
#  'S-30-D-077',
#  'S-30-D-049',
#  'F-30-D-046',
#  'F-30-D-069',
#  'F-30-D-071',
#  'S-30-096',
#  'F-30-175',
#  'F-30-160',
#  'S-30-D-034',
#  'F-30-D-065',
#  'F-30-102']
