# %%
import os
os.chdir(os.getenv("OUTPUT_DIR"))
params = "params.json"
output_path = "output"

# %%
import json
import sys
import pandas as pd 
from functools import reduce




with open(params,"r") as f:
    params = json.load(f)

def get_last_num(clade_name,num):
    clade_name_list = clade_name.split('|')
    return clade_name_list[len(clade_name_list)-num]

def get_last(clade_name):
    clade_name_list = clade_name.split('|')
    return clade_name_list[len(clade_name_list)-1]
def set_rank(taxonomy):
    if taxonomy.startswith("t__"):
        return "SGB"
    if taxonomy.startswith("s__"):
        return "SPECIES"
    elif  taxonomy.startswith("g__"):
        return "GENUS"
    elif  taxonomy.startswith("f__"):
        return "FAMILY"
    elif  taxonomy.startswith("o__"):
        return "ORDER"
    elif  taxonomy.startswith("c__"):
        return "CLASS"
    elif  taxonomy.startswith("p__"):
        return "PHYLUM"
    elif  taxonomy.startswith("k__"):
        return "KINGDOM"
def rename_taxonomy(taxonomy):
    if taxonomy.startswith("t__"):
        return taxonomy.replace("t__","").replace("_"," ")
    if taxonomy.startswith("s__"):
        return taxonomy.replace("s__","").replace("_"," ")
    elif  taxonomy.startswith("g__"):
        return taxonomy.replace("g__","").replace("_"," ")
    elif  taxonomy.startswith("f__"):
        return taxonomy.replace("f__","").replace("_"," ")
    elif  taxonomy.startswith("o__"):
        return taxonomy.replace("o__","").replace("_"," ")
    elif  taxonomy.startswith("c__"):
        return taxonomy.replace("c__","").replace("_"," ")
    elif  taxonomy.startswith("p__"):
        return taxonomy.replace("p__","").replace("_"," ")
    elif  taxonomy.startswith("k__"):
        return taxonomy.replace("k__","").replace("_"," ")
def get_one_df(file,sample_key):
    df = pd.read_csv(file,sep="\t",comment="#",header=None)
    df.columns = ["clade_name","ncbi_tax_id","relative_abundance","additional_species"]
    df = df.rename({"relative_abundance":sample_key},axis=1)
    df = df.drop("additional_species",axis=1)
    df = df.set_index(["clade_name","ncbi_tax_id"])
    return df    


metaphlan_sam_abundance=  params['metaphlan_sam_abundance']
df_list = [get_one_df(item['profile'],item['sample_name']) for item in metaphlan_sam_abundance]
df = reduce(lambda x,y:pd.merge(x,y,left_index=True,right_index=True, how="outer"),df_list)



df = df.reset_index()
df['taxonomy'] = df.apply(lambda x : get_last(x['clade_name']) ,axis=1)
df['tax_id'] = df.apply(lambda x : get_last(x['ncbi_tax_id']) ,axis=1)
df['rank'] = df.apply(lambda x : set_rank(x['taxonomy']) ,axis=1)
df['taxonomy'] = df.apply(lambda x : rename_taxonomy(x['taxonomy']) ,axis=1)
df = df.set_index(["clade_name","ncbi_tax_id","taxonomy","tax_id","rank"])
df = df.fillna(0)
df = df.reset_index()

# %%
# rank_list = list(set(df["rank"]))
# item = rank_list[0]

# %%
for item in rank_list:
    print(f"save: {output_path}/{item}.tsv")
    df.query("rank==@item").to_csv(f"{output_path}/{item}.tsv",sep="\t")
# Out:
# save: output/FAMILY.tsv
# save: output/SGB.tsv
# save: output/PHYLUM.tsv
# save: output/GENUS.tsv
# save: output/CLASS.tsv
# save: output/ORDER.tsv
# save: output/KINGDOM.tsv
# save: output/SPECIES.tsv

# %%
params = sys.argv[1]
output_path = sys.argv[2]

# %%
params = "/ssd1/wy/workspace2/nextflow_workspace/9a6af4fb-0af6-4752-af79-9adec161e7c2/4ae03b44-0418-4eeb-8b97-d37d83a9bbc3/86d2ce8c-9d23-42f2-a647-44838fc4a3c2/params.json"
output_path ="/ssd1/wy/workspace2/nextflow_workspace/9a6af4fb-0af6-4752-af79-9adec161e7c2/4ae03b44-0418-4eeb-8b97-d37d83a9bbc3/86d2ce8c-9d23-42f2-a647-44838fc4a3c2/output"

# %%
with open(params,"r") as f:
    params = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open(params,"r") as f:
#       2     params = json.load(f)
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:279, in _modified_open(file, *args, **kwargs)
#     277 @functools.wraps(io_open)
#     278 def _modified_open(file, *args, **kwargs):
# --> 279     if file in {0, 1, 2}:
#     280         raise ValueError(
#     281             f"IPython won't let you open fd={file} by default "
#     282             "as it is likely to crash IPython. If you know what you are doing, "
#     283             "you can use builtins' open."
#     284         )
#     286     return io_open(file, *args, **kwargs)
#
# TypeError: unhashable type: 'dict'

# %%
def get_last_num(clade_name,num):
    clade_name_list = clade_name.split('|')
    return clade_name_list[len(clade_name_list)-num]

def get_last(clade_name):
    clade_name_list = clade_name.split('|')
    return clade_name_list[len(clade_name_list)-1]
def set_rank(taxonomy):
    if taxonomy.startswith("t__"):
        return "SGB"
    if taxonomy.startswith("s__"):
        return "SPECIES"
    elif  taxonomy.startswith("g__"):
        return "GENUS"
    elif  taxonomy.startswith("f__"):
        return "FAMILY"
    elif  taxonomy.startswith("o__"):
        return "ORDER"
    elif  taxonomy.startswith("c__"):
        return "CLASS"
    elif  taxonomy.startswith("p__"):
        return "PHYLUM"
    elif  taxonomy.startswith("k__"):
        return "KINGDOM"
def rename_taxonomy(taxonomy):
    if taxonomy.startswith("t__"):
        return taxonomy.replace("t__","").replace("_"," ")
    if taxonomy.startswith("s__"):
        return taxonomy.replace("s__","").replace("_"," ")
    elif  taxonomy.startswith("g__"):
        return taxonomy.replace("g__","").replace("_"," ")
    elif  taxonomy.startswith("f__"):
        return taxonomy.replace("f__","").replace("_"," ")
    elif  taxonomy.startswith("o__"):
        return taxonomy.replace("o__","").replace("_"," ")
    elif  taxonomy.startswith("c__"):
        return taxonomy.replace("c__","").replace("_"," ")
    elif  taxonomy.startswith("p__"):
        return taxonomy.replace("p__","").replace("_"," ")
    elif  taxonomy.startswith("k__"):
        return taxonomy.replace("k__","").replace("_"," ")
def get_one_df(file,sample_key):
    df = pd.read_csv(file,sep="\t",comment="#",header=None)
    df.columns = ["clade_name","ncbi_tax_id","relative_abundance","additional_species"]
    df = df.rename({"relative_abundance":sample_key},axis=1)
    df = df.drop("additional_species",axis=1)
    df = df.set_index(["clade_name","ncbi_tax_id"])
    return df

# %%
metaphlan_sam_abundance=  params['metaphlan_sam_abundance']
df_list = [get_one_df(item['profile'],item['sample_name']) for item in metaphlan_sam_abundance]
df = reduce(lambda x,y:pd.merge(x,y,left_index=True,right_index=True, how="outer"),df_list)
df = df.reset_index()
df['taxonomy'] = df.apply(lambda x : get_last(x['clade_name']) ,axis=1)
df['tax_id'] = df.apply(lambda x : get_last(x['ncbi_tax_id']) ,axis=1)
df['rank'] = df.apply(lambda x : set_rank(x['taxonomy']) ,axis=1)
df['taxonomy'] = df.apply(lambda x : rename_taxonomy(x['taxonomy']) ,axis=1)
df = df.set_index(["clade_name","ncbi_tax_id","taxonomy","tax_id","rank"])
df = df.fillna(0)
df = df.reset_index()
df
# Out:
#                                              clade_name  \
# 0                                           k__Bacteria
# 1                         k__Bacteria|p__Actinobacteria
# 2        k__Bacteria|p__Actinobacteria|c__Actinomycetia
# 3     k__Bacteria|p__Actinobacteria|c__Actinomycetia...
# 4     k__Bacteria|p__Actinobacteria|c__Actinomycetia...
# ...                                                 ...
# 2496  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
# 2497  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
# 2498  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
# 2499  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
# 2500  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
#
#                                       ncbi_tax_id                 taxonomy  \
# 0                                               2                 Bacteria
# 1                                        2|201174           Actinobacteria
# 2                                   2|201174|1760            Actinomycetia
# 3                             2|201174|1760|85004        Bifidobacteriales
# 4                       2|201174|1760|85004|31953       Bifidobacteriaceae
# ...                                           ...                      ...
# 2496                         2|74201|203494|48461       Verrucomicrobiales
# 2497                 2|74201|203494|48461|1647988          Akkermansiaceae
# 2498          2|74201|203494|48461|1647988|239934              Akkermansia
# 2499   2|74201|203494|48461|1647988|239934|239935  Akkermansia muciniphila
# 2500  2|74201|203494|48461|1647988|239934|239935|                  SGB9226
#
#        tax_id     rank     OTF-17     OTF-14      ATF-8      MTF-8     OTF-18  \
# 0           2  KINGDOM  100.00000  100.00000  100.00000  100.00000  100.00000
# 1      201174   PHYLUM    0.64800    0.93605    2.26184    8.76117    1.30422
# 2        1760    CLASS    0.01800    0.04119    0.00000    0.65989    0.31119
# 3       85004    ORDER    0.00895    0.02008    0.00000    0.65743    0.18888
# 4       31953   FAMILY    0.00895    0.02008    0.00000    0.65743    0.18888
# ...       ...      ...        ...        ...        ...        ...        ...
# 2496    48461    ORDER    0.00000    0.00000    2.03925    0.00000    0.00331
# 2497  1647988   FAMILY    0.00000    0.00000    2.03925    0.00000    0.00331
# 2498   239934    GENUS    0.00000    0.00000    2.03925    0.00000    0.00331
# 2499   239935  SPECIES    0.00000    0.00000    2.03925    0.00000    0.00331
# 2500               SGB    0.00000    0.00000    2.03925    0.00000    0.00331
#
#       ...     ATF-20     MTF-12     OTF-16     ATF-11     MTF-14      MTF-9  \
# 0     ...  100.00000  100.00000  100.00000  100.00000  100.00000  100.00000
# 1     ...    2.85139   10.35850    0.43243    8.19303    4.96743    2.53879
# 2     ...    0.78088    3.33130    0.04631    2.01127    1.21351    0.77971
# 3     ...    0.78088    3.33130    0.00000    2.01127    1.17330    0.10573
# 4     ...    0.78088    3.33130    0.00000    2.01127    1.17330    0.10573
# ...   ...        ...        ...        ...        ...        ...        ...
# 2496  ...    0.24174    1.35988    0.00000    1.48418    0.26533    0.00000
# 2497  ...    0.24174    1.35988    0.00000    1.48418    0.26533    0.00000
# 2498  ...    0.24174    1.35988    0.00000    1.48418    0.26533    0.00000
# 2499  ...    0.24174    1.35988    0.00000    1.48418    0.26533    0.00000
# 2500  ...    0.24174    1.35988    0.00000    1.48418    0.26533    0.00000
#
#          ATF-12     OTF-13     MTF-10     MTF-17
# 0     100.00000  100.00000  100.00000  100.00000
# 1      11.17468    0.59813    5.36372    6.40959
# 2       2.32449    0.01016    0.91586    2.39596
# 3       2.32449    0.00000    0.83691    2.39596
# 4       2.32449    0.00000    0.83691    2.39596
# ...         ...        ...        ...        ...
# 2496    0.87621    0.15681    0.04829    0.29215
# 2497    0.87621    0.15681    0.04829    0.29215
# 2498    0.87621    0.15681    0.04829    0.29215
# 2499    0.87621    0.15681    0.04829    0.29215
# 2500    0.87621    0.15681    0.04829    0.29215
#
# [2501 rows x 35 columns]

# %%
df.to_csv(f"{output_path}/matrix.tsv",sep="\t",index=False)

# %%
# !id -u
# Out:
# 1002

# %%
# !ls -al  /ssd1/wy/workspace2/nextflow_workspace/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/output/metaphlan_sam/OTF-17/OTF-17_profile.txt
# Out:
# lrwxrwxrwx 1 1002 1002 147 Jun  6 10:09 /ssd1/wy/workspace2/nextflow_workspace/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/output/metaphlan_sam/OTF-17/OTF-17_profile.txt -> /data/wangyang/nf_work/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/1b/5b0d334f1e87189ffc5fe86523c82f/OTF-17_profile.txt

# %%
# !cat /data/wangyang/nf_work/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/1b/5b0d334f1e87189ffc5fe86523c82f/OTF-17_profile.txt
# Out:
# cat: /data/wangyang/nf_work/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/1b/5b0d334f1e87189ffc5fe86523c82f/OTF-17_profile.txt: No such file or directory

# %%
# !ls /data/wangyang/nf_work/leipu
# Out:
# /data/wangyang/nf_work/leipu

# %%
# !ls /data/wangyang/nf_work/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/1b/5b0d334f1e87189ffc5fe86523c82f/OTF-17_profile.txt
# Out:
# ls: cannot access '/data/wangyang/nf_work/leipu/pipeline_metaphlan_abundance/a3c9d483-87e4-40b9-8473-90edb4f6fb5d/1b/5b0d334f1e87189ffc5fe86523c82f/OTF-17_profile.txt': No such file or directory
