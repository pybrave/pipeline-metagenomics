# %%
import sys
sys.path.insert(0, "../../script/common")

# %%
# sys.path

# %%
import metaphlan
import json
import pandas as pd

# %%
params = "/ssd1/wy/workspace2/nextflow_workspace/a4f4acb2-e119-4a9e-8c59-cdea6bff3df5/b2cf5de7-a94d-4b44-84b7-7f0dd4c1fcef/2928f342-ba48-43bc-bfd9-f0746740817f/params.json"

# %%
with open(params,"r") as f:
    params = json.load(f)

# %%
metaphlan.get_abundance(params)
# Out:
#                                                                                                                                               test_s1  \
# clade_name                                         ncbi_tax_id                                taxonomy                      tax_id rank
# k__Bacteria                                        2                                          Bacteria                      2      KINGDOM  100.00000
# k__Bacteria|p__Bacteroidota                        2|976                                      Bacteroidota                  976    PHYLUM    63.49484
# k__Bacteria|p__Fusobacteria                        2|32066                                    Fusobacteria                  32066  PHYLUM    21.80173
# k__Bacteria|p__Firmicutes                          2|1239                                     Firmicutes                    1239   PHYLUM    13.94820
# ...

# %%
metaphlan.get_metadata(params)
# Out:
#               group
# sample_name
# test_s1      group2
# test_s2      group1
